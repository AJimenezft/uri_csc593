# %% [markdown]
# # Assignment 8
#
# *(Due Saturday, November 16, 2019 at noon.)*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

# %%
"""mydataset = pd.read_csv('../DataSet/rigradrates.csv')
mydataset.replace(to_replace="PS", value=None)
mydataset= mydataset.dropna()
mydataset

#Ri grad rate code
mydataset= mydataset.replace(to_replace="PS", value=None).dropna()
mydataset.filter(["ALL COHORT '16-17'", "STUDENT w/ DISABILITIES"]).plot()

#plt.plot(mydataset.filter(["ALL COHORT '16-17'"]))
#plt.plot(mydataset.filter(["ALL RATE '16-17'"]))
#plt.plot()
plt.show()

#mydataset.filter[]"""

survied = pd.read_csv('../DataSet/Survied.csv')
theydead = pd.read_csv('../DataSet/They Dead.csv')
#mydataset.replace(to_replace="1st", value= 1)
#mydataset.replace(to_replace="2nd", value= 2)
#mydataset.replace(to_replace="3rd", value= 3)

survied= survied.dropna().replace(to_replace="1st", value= 1).replace(to_replace="2nd", value= 2).replace(to_replace="3rd", value= 3)
theydead= theydead.dropna().replace(to_replace="1st", value= 1).replace(to_replace="2nd", value= 2).replace(to_replace="3rd", value= 3)
#print(list(mydataset.columns))

#titantic code
#mydataset.filter([list(mydataset.columns)[1], list(mydataset.columns)[2]]).plot()
#plt.plot(mydataset.filter(["PClass"]))
#plt.plot(mydataset.filter(["age"]))
#plt.plot(mydataset.loc[mydataset[list(mydataset.columns)[4]]==0].filter([list(mydataset.columns)[2]]))
#plt.plot(mydataset.loc[mydataset[list(mydataset.columns)[4]]==1].filter([list(mydataset.columns)[2]]))
plt.plot(survied.filter([list(survied.columns)[2]]),'g')
plt.plot(theydead.filter([list(theydead.columns)[2]]),'r')
plt.show()
#mydataset.loc[mydataset[list(mydataset.columns)[4]]==1].filter([list(mydataset.columns)[2]])


#mydataset.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Load your dataset and create at least one visualization involving at least two variables (columns). Explain the relevance of this graph in the Markdown cell below, and use comments to document the code you use to produce it.

# %%
#The graph above graphed the people who survied and the people who passed "TheyDead." away as the result of the tradgedy. The Y is the ages of the passangers, X is represntive of the passangers.

# %% [markdown]
# #Unfortunately, this is the best I can produce with the overcomplicated table that I chose. My intentions was to pull up all cohort and from the total number, pull out the amount of student graduate w/ a disability. I am considering changing my whole dataset for the sake of the final project
