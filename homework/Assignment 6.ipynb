# %% [markdown]
# # Assignment 6
#
# *(Due Saturday, October 26, 2019 at noon.)*

# %% [markdown]
# **1)** Below, paste the code needed to import and clean your file from the `../dataset` directory in your repository, then save the result to a new file. I should be able to run the code in this notebook and get my own copy of your cleaned, processed data.
#
# **Note:** Your assignment file will be publicly accessible on Github. If your dataset is private, don't print anything confidential in this assignment.

# %%
import pandas as pd

mydataset = pd.read_csv('../DataSet/rigradrates.csv')
mydataset.fillna(0)

mydataset.replace(to_replace="PS", value=None)
# Out:
#       STATE NAME  FIPST  DISCTRICT NCES ID ST_LEAID  \
# 0   RHODE ISLAND     44            4400001    RI-50
# 1   RHODE ISLAND     44            4400003    RI-60
# 2   RHODE ISLAND     44            4400004    RI-40
# 3   RHODE ISLAND     44            4400008    RI-58
# 4   RHODE ISLAND     44            4400009    RI-67
# 5   RHODE ISLAND     44            4400015    RI-47
# 6   RHODE ISLAND     44            4400017    RI-62
# 7   RHODE ISLAND     44            4400018    RI-61
# 8   RHODE ISLAND     44            4400019    RI-63
# 9   RHODE ISLAND     44            4400024    RI-42
# 10  RHODE ISLAND     44            4400025    RI-64
# 11  RHODE ISLAND     44            4400030    RI-01
# 12  RHODE ISLAND     44            4400031    RI-48
# 13  RHODE ISLAND     44            4400032    RI-51
# 14  RHODE ISLAND     44            4400036    RI-54
# 15  RHODE ISLAND     44            4400065    RI-96
# 16  RHODE ISLAND     44            4400090    RI-03
# 17  RHODE ISLAND     44            4400120    RI-04
# 18  RHODE ISLAND     44            4400150    RI-98
# 19  RHODE ISLAND     44            4400210    RI-06
# 20  RHODE ISLAND     44            4400240    RI-07
# 21  RHODE ISLAND     44            4400270    RI-08
# 22  RHODE ISLAND     44            4400300    RI-09
# 23  RHODE ISLAND     44            4400330    RI-10
# 24  RHODE ISLAND     44            4400360    RI-97
# 25  RHODE ISLAND     44            4400420    RI-99
# 26  RHODE ISLAND     44            4400510    RI-15
# 27  RHODE ISLAND     44            4400540    RI-16
# 28  RHODE ISLAND     44            4400570    RI-17
# 29  RHODE ISLAND     44            4400630    RI-19
# 30  RHODE ISLAND     44            4400660    RI-20
# 31  RHODE ISLAND     44            4400690    RI-22
# 32  RHODE ISLAND     44            4400720    RI-21
# 33  RHODE ISLAND     44            4400750    RI-23
# 34  RHODE ISLAND     44            4400780    RI-24
# 35  RHODE ISLAND     44            4400810    RI-25
# 36  RHODE ISLAND     44            4400840    RI-26
# 37  RHODE ISLAND     44            4400870    RI-27
# 38  RHODE ISLAND     44            4400900    RI-28
# 39  RHODE ISLAND     44            4400960    RI-30
# 40  RHODE ISLAND     44            4400990    RI-31
# 41  RHODE ISLAND     44            4401020    RI-32
# 42  RHODE ISLAND     44            4401050    RI-33
# 43  RHODE ISLAND     44            4401110    RI-35
# 44  RHODE ISLAND     44            4401140    RI-38
# 45  RHODE ISLAND     44            4401170    RI-36
#
#                                    DISTRICT NAME  ALL COHORT '16-17'  \
# 0                          R.I. Sch for the Deaf                   6
# 1                            MET Career and Tech                 203
# 2                         Davies Career and Tech                 160
# 3                          Beacon Charter School                  55
# 4                                           DCYF                  36
# 5   Blackstone Valley Prep  A RI Mayoral Academy                   1
# 6                              The Greene School                  45
# 7        Trinity Academy for the Performing Arts                  27
# 8   Rhode Island Nurses Institute Middle College                  46
# 9          Sheila Skip Nowell Leadership Academy                  77
# 10                         Village Green Virtual                  67
# 11                                    Barrington                 248
# 12                                    Highlander                  20
# 13                       Paul Cuffee Charter Sch                  60
# 14                            Blackstone Academy                  43
# 15                                Bristol Warren                 213
# 16                                  Burrillville                 165
# 17                                 Central Falls                 173
# 18                                       Chariho                 326
# 19                                      Coventry                 350
# 20                                      Cranston                 751
# 21                                    Cumberland                 317
# 22                                East Greenwich                 139
# 23                               East Providence                 342
# 24                         Exeter-West Greenwich                 133
# 25                              Foster-Glocester                 147
# 26                                     Jamestown                   1
# 27                                      Johnston                 208
# 28                                       Lincoln                 194
# 29                                    Middletown                 152
# 30                                  Narragansett                  96
# 31                                  New Shoreham                   7
# 32                                       Newport                 138
# 33                               North Kingstown                 325
# 34                              North Providence                 215
# 35                              North Smithfield                 116
# 36                                     Pawtucket                 534
# 37                                    Portsmouth                 246
# 38                                    Providence                1479
# 39                                      Scituate                 105
# 40                                    Smithfield                 190
# 41                               South Kingstown                 239
# 42                                      Tiverton                 133
# 43                                       Warwick                 625
# 44                                  West Warwick                 211
# 45                                      Westerly                 215
#
#    ALL RATE '16-17'  AMERICAN INDIAN/ALASKA NATIVE (MAM) MAM RATE  \
# 0              GE50                                  NaN      NaN
# 1                90                                  2.0      NaN
# 2             80-84                                  1.0      NaN
# 3              GE90                                  2.0      NaN
# 4            19-Nov                                  NaN      NaN
# 5            19-Nov                                  NaN      NaN
# 6              GE90                                  1.0      NaN
# 7              GE80                                  NaN      NaN
# 8            19-Nov                                  NaN      NaN
# 9             15-19                                  1.0      NaN
# 10             GE95                                  NaN      NaN
# 11               96                                  1.0      NaN
# 12             GE80                                  NaN      NaN
# 13             GE90                                  2.0      NaN
# 14            80-89                                  NaN      NaN
# 15               90                                  2.0      NaN
# 16            85-89                                  2.0      NaN
# 17            75-79                                  3.0      NaN
# 18               90                                  8.0     GE50
# 19               90                                  3.0     GE50
# 20               86                                  7.0     GE50
# 21               87                                  NaN      NaN
# 22             GE95                                  NaN      NaN
# 23               82                                  3.0      NaN
# 24            90-94                                  NaN      NaN
# 25            90-94                                  1.0      NaN
# 26            90-94                                  NaN      NaN
# 27               78                                  NaN      NaN
# 28            85-89                                  NaN      NaN
# 29            90-94                                  1.0      NaN
# 30            90-94                                  NaN      NaN
# 31             GE50                                  NaN      NaN
# 32            80-84                                  3.0      NaN
# 33               90                                  1.0      NaN
# 34               91                                  2.0      NaN
# 35            90-94                                  NaN      NaN
# 36               82                                  NaN      NaN
# 37               96                                  2.0      NaN
# 38               75                                  9.0     LT50
# 39             GE95                                  NaN      NaN
# 40            90-94                                  NaN      NaN
# 41               94                                  7.0     GE50
# 42            80-84                                  NaN      NaN
# 43               86                                  1.0      NaN
# 44               84                                  3.0      NaN
# 45               87                                  4.0      NaN
#
#     ASIAN/PACIFIC ISLANDER(MAS)  ... MTR RATE  WHITE (MWH) MWH RATE  \
# 0                           NaN  ...      NaN          3.0       PS
# 1                           6.0  ...     GE50         76.0    85-89
# 2                           2.0  ...     GE50         68.0    75-79
# 3                           3.0  ...     GE50         36.0     GE90
# 4                           1.0  ...     GE50         14.0     LT50
# 5                           NaN  ...     GE50          NaN      NaN
# 6                           NaN  ...     GE50         31.0     GE90
# 7                           1.0  ...     GE50          1.0     GE90
# 8                           NaN  ...     GE50         13.0     LT50
# 9                           1.0  ...     GE50         11.0     LT50
# 10                          2.0  ...     GE50         21.0     GE80
# 11                         18.0  ...     GE50        219.0     GE95
# 12                          NaN  ...     GE50          2.0     GE95
# 13                          1.0  ...      NaN          2.0     GE95
# 14                          NaN  ...     GE50          5.0     GE95
# 15                          3.0  ...     GE50        190.0    90-94
# 16                          1.0  ...     GE50        152.0    85-89
# 17                          NaN  ...     GE50         14.0     GE50
# 18                          2.0  ...     GE50        297.0    90-94
# 19                          6.0  ...     GE50        321.0       91
# 20                         48.0  ...     GE80        445.0       87
# 21                          3.0  ...     GE50        266.0    85-89
# 22                          5.0  ...     GE50        124.0     GE95
# 23                          7.0  ...     GE50        263.0    80-84
# 24                          NaN  ...     GE50        124.0    90-94
# 25                          3.0  ...     GE50        141.0    90-94
# 26                          NaN  ...      NaN          1.0    90-94
# 27                          6.0  ...      NaN        163.0    75-79
# 28                          5.0  ...      NaN        166.0    90-94
# 29                          2.0  ...      NaN        117.0    90-94
# 30                          NaN  ...      NaN         91.0    90-94
# 31                          NaN  ...      NaN          4.0    90-94
# 32                          1.0  ...     GE50         54.0     GE90
# 33                         10.0  ...     GE50        301.0       90
# 34                          7.0  ...     GE50        139.0    90-94
# 35                          3.0  ...      NaN        102.0    90-94
# 36                         12.0  ...     GE80        167.0    80-84
# 37                          5.0  ...     GE50        218.0     GE95
# 38                         71.0  ...    60-69        155.0    75-79
# 39                          2.0  ...      NaN        101.0     GE95
# 40                          3.0  ...      NaN        178.0    90-94
# 41                          4.0  ...     GE50        207.0     GE95
# 42                          NaN  ...     GE50        127.0    80-84
# 43                         18.0  ...     GE50        527.0       86
# 44                          6.0  ...     GE50        159.0    80-84
# 45                          7.0  ...     GE50        180.0    85-89
#
#     STUDENT w/ DISABILITIES CWD RATE  ECD COHORT ECD RATE  \
# 0                       5.0       PS           5       PS
# 1                      36.0    70-79         167    85-89
# 2                      15.0     GE50         130    75-79
# 3                       7.0     GE50          33     GE90
# 4                      13.0     LT50          31   19-Nov
# 5                       1.0     LT50           1   19-Nov
# 6                       4.0     LT50          10     GE50
# 7                       2.0     LT50          27     GE80
# 8                       5.0     LT50          44   19-Nov
# 9                      17.0     LE20          73    15-19
# 10                     10.0     GE50          64     GE95
# 11                     35.0    70-79          21     GE80
# 12                      8.0     GE50          20     GE80
# 13                     16.0     GE80          58     GE90
# 14                      8.0     GE50          38    80-89
# 15                     25.0    60-79          90    80-84
# 16                     15.0     LT50          60    70-79
# 17                     43.0    60-69         164    75-79
# 18                     39.0    60-69          96    80-84
# 19                     57.0    70-79         134    75-79
# 20                    110.0    55-59         361       80
# 21                     50.0    60-69         101    70-74
# 22                     14.0     GE50          10     GE50
# 23                     52.0    60-69         194    75-79
# 24                     23.0    60-79          25     GE80
# 25                      9.0     LT50          33     GE90
# 26                      1.0     LT50           1     GE90
# 27                     45.0    60-69         109    65-69
# 28                     20.0    40-59          57    70-79
# 29                     32.0    70-79          50    80-89
# 30                     19.0    60-79          30     GE80
# 31                      NaN      NaN           1     GE80
# 32                     23.0    60-79          91    75-79
# 33                     39.0    60-69          61    70-74
# 34                     49.0    60-69         109    80-84
# 35                     18.0     GE80          21    60-79
# 36                     84.0    65-69         462       81
# 37                     33.0    80-89          38    80-89
# 38                    244.0    50-54        1363       75
# 39                      8.0     GE50          21     GE80
# 40                     25.0    40-59          48    70-79
# 41                     22.0    40-59          44    70-79
# 42                     32.0    70-79          52    70-79
# 43                    111.0    65-69         277    75-79
# 44                     58.0    60-69         127    80-84
# 45                     47.0    60-69          85    70-74
#
#     LIMITED PROFICIENCY (LEP) LEP RATE    DATE_CUR
# 0                         1.0        PS  17-Aug-18
# 1                        10.0      GE50  17-Aug-18
# 2                        17.0      GE80  17-Aug-18
# 3                         NaN       NaN  17-Aug-18
# 4                         3.0       NaN  17-Aug-18
# 5                         NaN       NaN  17-Aug-18
# 6                         1.0       NaN  17-Aug-18
# 7                         1.0       NaN  17-Aug-18
# 8                         5.0       NaN  17-Aug-18
# 9                        14.0      LT50  17-Aug-18
# 10                        3.0      LT50  17-Aug-18
# 11                        3.0      LT50  17-Aug-18
# 12                        4.0      LT50  17-Aug-18
# 13                        5.0      LT50  17-Aug-18
# 14                        3.0      LT50  17-Aug-18
# 15                        2.0      LT50  17-Aug-18
# 16                        NaN       NaN  17-Aug-18
# 17                       77.0     80-84  17-Aug-18
# 18                        NaN       NaN  17-Aug-18
# 19                        NaN       NaN  17-Aug-18
# 20                       42.0     80-89  17-Aug-18
# 21                        2.0     80-89  17-Aug-18
# 22                        NaN       NaN  17-Aug-18
# 23                       11.0      GE50  17-Aug-18
# 24                        1.0      GE50  17-Aug-18
# 25                        NaN       NaN  17-Aug-18
# 26                        NaN       NaN  17-Aug-18
# 27                        8.0      GE50  17-Aug-18
# 28                        2.0      GE50  17-Aug-18
# 29                        1.0      GE50  17-Aug-18
# 30                        NaN       NaN  17-Aug-18
# 31                        2.0       NaN  17-Aug-18
# 32                       16.0     21-39  17-Aug-18
# 33                        5.0     21-39  17-Aug-18
# 34                        4.0     21-39  17-Aug-18
# 35                        1.0     21-39  17-Aug-18
# 36                       93.0     85-89  17-Aug-18
# 37                        2.0     85-89  17-Aug-18
# 38                      375.0        68  17-Aug-18
# 39                        NaN       NaN  17-Aug-18
# 40                        1.0       NaN  17-Aug-18
# 41                        2.0       NaN  17-Aug-18
# 42                        1.0       NaN  17-Aug-18
# 43                        7.0      GE50  17-Aug-18
# 44                        5.0      GE50  17-Aug-18
# 45                        3.0      GE50  17-Aug-18
#
# [46 rows x 26 columns]

# %%
#Save your file (change the name if necessary).
mydataset.to_csv('../dataset/ds.csv')

# %% [markdown]
# **2)** A brief survey: Have you taken an introductory statistics course, and if so, do you remember much from it? For example,
#
# * Can you articulate the null hypotheses for the questions you formulated last week involving your data?
# * Do you know what a t-test is for?
# * Do you know what a *p* value represents?
# * Do you know what standard deviation is, and how it's calculated?

# %%
# ANSWERS.

#1. No. I am not familiar with that function at the moment.
#2. I am not 100% on what a t-test is.
#3. I only know of the P-value as it related to human resources, and then only a little.
#4. I know what standard deviation is, I don't know how to calculate it.

# %% [markdown]
# #### Submitting
#
# In the Terminal (Mac) or Git Bash (Windows):
#
# `git commit -a -m 'Assignment 6 completed'`
# `git push`

# %% [markdown]
# ### Reading
#
# 1. [_Python for Data Analysis_](https://uri-primo.hosted.exlibrisgroup.com/permalink/f/10nopmq/01URI_ALMA51209454630002396):
#     * Section 7.3
#     * Chapter 10
